# %%
#--------------------------------------
# Error Calculation of rust results
#--------------------------------------

import numpy as np
import pandas as pd
import hemispherical_electrode as he
from scipy.integrate import cumulative_trapezoid

# Load the export file names 
Export_Name = "rs_benchmark/Export_Name.csv"
df_exp = pd.read_csv(Export_Name)
FILENAME = df_exp.columns[0]

# Load Dataframe with time and element infos
df =  pd.read_csv(('rs_benchmark/' + FILENAME + '_time.csv'))

df['e_FRLT_max'] = np.zeros(len(df['N']))
df['e_G1_max'] = np.zeros(len(df['N']))
df['e_R1_max'] = np.zeros(len(df['N']))
df['e_rel_FRLT_max'] = np.zeros(len(df['N']))
df['e_rel_G1_max'] = np.zeros(len(df['N']))
df['e_rel_R1_max'] = np.zeros(len(df['N']))

# import values and calculate errors
for i in range(0, len(df['N'])):
    # No. of Elems
    N = df['N'][i]
    # generate test potential
    [t,I] = he.current_hemispherical1(N_max =N); # with default values
    # Reference values
    d_ref = cumulative_trapezoid(I,t)
    # Import results 
    df_ru = pd.read_csv(('rs_benchmark/' + FILENAME + '_' + str(df['N'][i]) + '.csv'))

    # FRLT alg
    #-------------------------------
    d_FRLT = df_ru['res_FRLT'][1:] # first value is zero
    # (max) absolute error
    e_FRLT = np.abs(d_FRLT - d_ref)
    df['e_FRLT_max'][i] = np.max(e_FRLT)
    # (max) relative error
    e_rel_FRLT = e_FRLT/(np.abs(d_ref))
    df['e_rel_FRLT_max'][i] = np.max(e_rel_FRLT)

    # G1 alg
    #-------------------------------
    d_G1 = df_ru['res_G1'][:-1]
    # absolute error
    e_G1 = np.abs(d_G1-d_ref)
    df['e_G1_max'][i] = np.max(e_G1)
    # relative error
    e_rel_G1 = e_G1/(np.abs(d_ref))
    df['e_rel_G1_max'][i] = np.max(e_rel_G1)

    # R1 alg
    #-------------------------------
    d_R1 = df_ru['res_R1'][:-1]
    # absolute error
    e_R1 = np.abs(d_R1-d_ref)
    df['e_R1_max'][i] = np.max(e_R1)
    # relative error
    e_rel_R1 = e_R1/(np.abs(d_ref))
    df['e_rel_R1_max'][i] = np.max(e_rel_R1)

# export all results
#df.to_csv('rs_benchmark/Rust_Benchmark_Results.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'e_FRLT_max'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 36
#      34 # (max) absolute error
#      35 e_FRLT = np.abs(d_FRLT - d_ref)
# ---> 36 df['e_FRLT_max'][i] = np.max(e_FRLT)
#      37 # (max) relative error
#      38 e_rel_FRLT = e_FRLT/(np.abs(d_ref))
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3805, in DataFrame.__getitem__(self, key)
#    3803 if self.columns.nlevels > 1:
#    3804     return self._getitem_multilevel(key)
# -> 3805 indexer = self.columns.get_loc(key)
#    3806 if is_integer(indexer):
#    3807     indexer = [indexer]
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key, method, tolerance)
#    3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
# -> 3805     raise KeyError(key) from err
#    3806 except TypeError:
#    3807     # If we have a listlike key, _check_indexing_error will raise
#    3808     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3809     #  the TypeError.
#    3810     self._check_indexing_error(key)
#
# KeyError: 'e_FRLT_max'
